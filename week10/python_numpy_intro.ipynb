# %% [markdown]
# # Mehmet Arif Biyik
# ## Week 10
# ### Python Numpy into

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.19.5'

# %%
arr = np.array([1,2 , 3,4, 5,6])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr2 = np.array(50)

# %%
arr2
# Out:
# array(50)

# %%
print(arr2)
# Out:
# 50

# %%
arr3 = np.array([1,2 ,3,4,5,6])

# %%
print(arr3)
# Out:
# [1 2 3 4 5 6]

# %%
arr4 = np.array([[1,2,3,4,5,6], [[11,22,33,44,55,66]]])
print(arr4)
# Out:
# [list([1, 2, 3, 4, 5, 6]) list([[11, 22, 33, 44, 55, 66]])]
# /srv/conda/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.

# %%
arr5 = np.array([ [[1,2,3], [4,5,6]], [[11,22,33], [44,55,66]]])

# %%
print(arr5)
# Out:
# [[[ 1  2  3]
#   [ 4  5  6]]
#
#  [[11 22 33]
#   [44 55 66]]]

# %%
print(arr2.ndim)
# Out:
# 0

# %%
print(arr4.ndim)
# Out:
# 1

# %%
print(arr5.ndim)
# Out:
# 3

# %%
print(arr3)
# Out:
# [1 2 3 4 5 6]

# %%
print(arr3[-1])
# Out:
# 6

# %%
print(arr5[0,1,1])
# Out:
# 5

# %%
marr = np.array([1,2,3,4,5])

# %%
print(arr5[0, -1])
# Out:
# [4 5 6]

# %%
print(arr3)
# Out:
# [1 2 3 4 5 6]

# %%
print(arr3[:3])
# Out:
# [1 2 3]

# %%
print(arr3[-3:-1])
# Out:
# [4 5]

# %%
print(arr3[1:5:2])
# Out:
# [2 4]
