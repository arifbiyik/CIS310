# %% [markdown]
# # Mehmet Arif Biyik
# ## Week 5
# ### Python Files basics

# %%
# %%writefile file.txt
# hi, i am a student in CIS350
# Out:
# Writing file.txt

# %%
ls
# Out:
# file.txt  pyton_loops.ipynb  pyton_statements.ipynb  Untitled.ipynb

# %%
pwd
# Out:
# '/home/jovyan/demo/wk5'

# %%
f = open("myFile.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-dbdd91f01b0a> in <module>
# ----> 1 f = open("myFile.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myFile.txt'

# %%
f = open("file.txt")

# %%
f.read()
# Out:
# 'hi, i am a student in CIS350\n'

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'hi, i am a student in CIS350\n'

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
f.readlines()
# Out:
# ['hi, i am a student in CIS350\n']

# %%
# %%writefile demofile.txt
# Hi, Welcome to python Files
# this file is only for testing.
# you can put any text in it.
# Good Luck
# Out:
# Writing demofile.txt

# %%
ls
# Out:
# demofile.txt  Python_files.ipynb  pyton_statements.ipynb
# file.txt      pyton_loops.ipynb

# %%
myFile = open("demofile.txt", "r")

# %%
myFile.read()
# Out:
# 'Hi, Welcome to python Files\nthis file is only for testing.\nyou can put any text in it.\nGood Luck\n'

# %%
myFile.readline()
# Out:
# ''

# %%
myFile.seek(0)
myFile.readline()
# Out:
# 'Hi, Welcome to python Files\n'

# %%
myFile.readline()
# Out:
# 'this file is only for testing.\n'

# %%
myFile.seek(0)
# Out:
# 0

# %%
myFile.readlines()
# Out:
# ['Hi, Welcome to python Files\n',
#  'this file is only for testing.\n',
#  'you can put any text in it.\n',
#  'Good Luck\n']

# %%
fw = open("file1.txt", "w")
