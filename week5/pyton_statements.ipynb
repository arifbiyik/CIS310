# %% [markdown]
# # Mehmet Arif Biyik
# ## Week 5
# ### Python Statements

# %%
if True:
    print("It was correct!")
# Out:
# It was correct!

# %%
value= 5

if value == 5:
     print("Hi Five!")
else:
    print("Lets try again!")
# Out:
# Hi Five!

# %%
value = 6

if value == 5:
        print("Hi Five")
else:
        print("Lets try again!")
# Out:
# Lets try again!

# %%
test1 = 89
test2 = 79

if   test1 > test2:
    print("Test1 is greater than test2")
    print("You may think to redo test2")
elif test2 > test1:
    print("test 2 is greater than test1")
    print("you may think about redoing test1, instead")
    
else: 
    print("test 1 and test 2 are equal")

# %%
#short hand
if test1 > test2:print("test 1 is greater than test2")
