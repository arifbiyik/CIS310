# %% [markdown]
# # Mehmet Arif Biyik
# ## 01/24/2021
# ### Python- Practice Number

# %%
5 + 5
# Out:
# 10

# %%
10 - 5
# Out:
# 5

# %%
4 * 3
# Out:
# 12

# %%
12/3
# Out:
# 4.0

# %%
12-5/5
# Out:
# 11.0

# %%
4**2
# Out:
# 16

# %%
5 % 2
# Out:
# 1

# %%
average = 3.5

# %%
average
# Out:
# 3.5

# %%
num_hour = 10
avg_pay = 9.88

# %%
total_pay = num_hour * avg_pay

# %%
total_pay
# Out:
# 98.80000000000001
